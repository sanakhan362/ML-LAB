# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df=pd.read_csv("Car_sales.csv")
print(df)
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
print(df.head(10))
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
# 5  Audi           A6                             18.780              23.555
# 6  Audi           A8                              1.380                  39
# 7  BMW            323i                           19.747                   .
# 8  BMW            328i                            9.231              28.675
# 9  BMW            528i                           17.527              36.125
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# ...

# %%
import pandas as pd
df=pd.read_csv("Car_sales.csv")
num_att=df.shape[1]
print("no of attributes",num_att)
# Out:
# no of attributes 15

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales in thousands   157 non-null    float64
#  3   4-year resale value  157 non-null    object
#  4   Vehicle type         157 non-null    object
#  5   Price in thousands   157 non-null    object
#  6   Engine size          157 non-null    object
#  7   Horsepower           157 non-null    object
#  8   Wheelbase            157 non-null    object
#  9   Width                157 non-null    object
#  10  Length               157 non-null    object
#  11  Curb weight          157 non-null    object
#  12  Fuel capacity        157 non-null    object
#  13  Fuel efficiency      157 non-null    object
#  14  Latest Launch        157 non-null    object
# ...

# %%
print(df.isnull())
# Out:
#      Manufacturer  Model  Sales in thousands  4-year resale value  \
# 0           False  False               False                False
# 1           False  False               False                False
# 2           False  False               False                False
# 3           False  False               False                False
# 4           False  False               False                False
# ..            ...    ...                 ...                  ...
# 152         False  False               False                False
# 153         False  False               False                False
# 154         False  False               False                False
# 155         False  False               False                False
# 156         False  False               False                False
#
#      Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  \
# 0           False               False        False       False      False
# ...

# %%
#print columns and rows
num_rows,num_columns=df.shape
print("no of rows",num_rows)
print("no of columns",num_columns)
# Out:
# no of rows 157
# no of columns 15

# %%
#print all rows
print(df.iloc[:])
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
#print all columns
print(df.iloc[:,:])
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
#print dupicates
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 152    False
# 153    False
# 154    False
# 155    False
# 156    False
# Length: 157, dtype: bool

# %%
#drop dupplicates
print(df.drop_duplicates)
# Out:
# <bound method DataFrame.drop_duplicates of       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# ...

# %%
df.shape[0]
# Out:
# 157

# %%
#missing values in each colums
print("no of missing values:")
print(df.isnull())
# Out:
# no of missing values:
#      Manufacturer  Model  Sales in thousands  4-year resale value  \
# 0           False  False               False                False
# 1           False  False               False                False
# 2           False  False               False                False
# 3           False  False               False                False
# 4           False  False               False                False
# ..            ...    ...                 ...                  ...
# 152         False  False               False                False
# 153         False  False               False                False
# 154         False  False               False                False
# 155         False  False               False                False
# 156         False  False               False                False
#
#      Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  \
# 0           False               False        False       False      False
# ...

# %%
print(df.isnull().sum())
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %%
#print the most missing values
df.isnull().sum().idxmax()
df
df['ram']=df['Model']
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
#drop paricular column
df.drop(columns=['ram'])
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df['slaray']=df['Model']
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df.drop(columns=['slaray'])
df.drop(columns=['ram'])
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
print(df.isnull().sum())
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# ram                    0
# slaray                 0
# dtype: int64

# %%
df['Model'].fillna(df['Length'].mean())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:1630, in _ensure_numeric(x)
#    1629 try:
# -> 1630     x = float(x)
#    1631 except (TypeError, ValueError):
#    1632     # e.g. "1+1j" or "foo"
#
# ...

# %%
#function to define min max values
def find_min_max(df,column_name):
    min_val=df['Length'].min()
    max_val=df['Width'].max()
    print(max_val)
    print(min_val)

# %%
#find the rows and columns

min_row=df[df['Length']==min_val]
max_row=df[df['Width']==max_val]
min_row
max_row
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 #find the rows and columns
# ----> 3 min_row=df[df['Length']==min_val]
#       4 max_row=df[df['Width']==max_val]
#       5 min_row
#
# NameError: name 'min_val' is not defined

# %%
print(df['Model'].min)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.min of 0      Integra
# 1      TL
# 2      CL
# 3      RL
# 4      A4
#              ...
# 152    V40
# 153    S70
# 154    V70
# 155    C70
# 156    S80
# Name: Model, Length: 157, dtype: object>

# %%
#print min value in the row mode
print(df['Length'].min)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.min of 0      172.4
# 1      192.9
# 2        192
# 3      196.6
# 4        178
#        ...
# 152    176.6
# 153    185.9
# 154    186.2
# 155    185.7
# 156    189.8
# Name: Length, Length: 157, dtype: object>

# %%
df['Width'].min()
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df[df['Model']==min_val]
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df[df['Model']==min_val]
#       2 df
#
# NameError: name 'min_val' is not defined

# %%
#horse power
hp_min=df['Horsepower'].min()
hp_max=df['Horsepower'].max()
print(hp_max)
# Out:
# 92
