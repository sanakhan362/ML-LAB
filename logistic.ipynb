# %%
import pandas as pd
df=pd.read_csv("Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
print(df.shape)
# Out:
# (150, 6)

# %%
print(df.dtypes)
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
print(list(df.columns))
# Out:
# ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']

# %%
print(df.head(5))
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print(df.tail(5))
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
print(df["Species"].unique())
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
print(df["Species"].value_counts())
print(df.isnull().sum())
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df=df.drop(columns="Id")
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
print(df.describe())
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
X=df.drop(columns='Species')
y=df["Species"]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
for col in X.columns:
    plt.figure(figsize=(12,6))
    sns.histplot(x=df[col],kde=True,color="blue")
    plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x=df["SepalLengthCm"],y=df["SepalWidthCm"],color="blue",legend=True)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x=df["SepalLengthCm"],y=df["SepalWidthCm"],color="blue")
plt.show()

# %%
sns.boxplot(x='Species', y='PetalWidthCm', data=df)

plt.title('Boxplot of Petal Width for Each Iris Species')
plt.xlabel('Species')
plt.ylabel('Petal Width (cm)')
plt.xticks(rotation=45)  # Optional: rotate labels for better visibility
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y="PetalLengthCm",x="Species",data=df)
plt.show()

# %%
sns.pairplot(df,hue="Species")
plt.show()

# %%
print(df['PetalLengthCm'].corr(df["PetalWidthCm"]))
# Out:
# 0.9627570970509663

# %%
X=df.drop(columns="Species")
y=df["Species"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)
print(X_train.shape)
# Out:
# (105, 4)

# %%
from sklearn.svm import SVC
model=SVC()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
print(y_pred)
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-versicolor' 'Iris-setosa'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-virginica' 'Iris-setosa'
#  'Iris-setosa' 'Iris-virginica' 'Iris-versicolor' 'Iris-setosa'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-setosa' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-setosa'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-setosa' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-virginica' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-virginica' 'Iris-virginica' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-virginica' 'Iris-setosa' 'Iris-virginica' 'Iris-virginica'
#  'Iris-versicolor']

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Species']=le.fit_transform(df['Species'])
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0              5.1           3.5            1.4           0.2        0
# 1              4.9           3.0            1.4           0.2        0
# 2              4.7           3.2            1.3           0.2        0
# 3              4.6           3.1            1.5           0.2        0
# 4              5.0           3.6            1.4           0.2        0
# ..             ...           ...            ...           ...      ...
# 145            6.7           3.0            5.2           2.3        2
# 146            6.3           2.5            5.0           1.9        2
# 147            6.5           3.0            5.2           2.0        2
# 148            6.2           3.4            5.4           2.3        2
# 149            5.9           3.0            5.1           1.8        2
#
# [150 rows x 5 columns]

# %%
model=SVC(C=1)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report,recall_score,precision_score,f1_score
print(confusion_matrix(y_pred,y_test))
# Out:
# [[14  0  0]
#  [ 0 17  0]
#  [ 0  1 13]]

# %%
print(accuracy_score(y_pred,y_test))
print(classification_report(y_pred,y_test))
print(recall_score(y_pred,y_test,average='macro'))
print(f1_score(y_pred,y_test,average='macro'))
print(precision_score(y_pred,y_test,average='macro'))
# Out:
# 0.9777777777777777
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        14
# Iris-versicolor       0.94      1.00      0.97        17
#  Iris-virginica       1.00      0.93      0.96        14
#
#        accuracy                           0.98        45
#       macro avg       0.98      0.98      0.98        45
#    weighted avg       0.98      0.98      0.98        45
#
# 0.9761904761904763
# 0.9781305114638448
# 0.9814814814814815

# %%
from sklearn.model_selection import KFold,cross_val_score
kf=KFold(n_splits=5,shuffle=True,random_state=1)  #split dataset into 5 folds
cv=cross_val_score(model,X,y,cv=kf)# shuffle the data before split into folds
print("accuracy of each fold",cv)
print("mean accuracy:",cv.mean())
# Out:
# accuracy of each fold [0.96666667 0.93333333 0.9        0.96666667 0.96666667]
# mean accuracy: 0.9466666666666667

# %%
from sklearn.model_selection import GridSearchCV
param_g={'C':[0.1,1,10,100,1000]}      #
grid=GridSearchCV(SVC(),param_g,cv=5,return_train_score=True)
grid.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(), param_grid={'C': [0.1, 1, 10, 100, 1000]},
#              return_train_score=True)

# %%
from sklearn.model_selection import GridSearchCV
param_g={'C':[0.1,1,10,101]}
grid=GridSearchCV(SVC(),param_g,cv=5,return_train_score=True)
grid.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-de714c9743a6> in <module>
#       1 from sklearn.model_selection import GridSearchCV
#       2 param_g={'C':[0.1,1,10,101]}
# ----> 3 grid=GridSearchCV(SVC(),param_g,cv=5,return_train_score=True)
#       4 grid.fit(X,y)
#
# NameError: name 'SVC' is not defined

# %%
best_model=grid.best_estimator_
best_model.fit(X_train,y_train)
# Out:
# SVC(C=10)

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier()
tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
result=pd.DataFrame(grid.cv_results_)
print(result[['param_C','mean_test_score','rank_test_score']])
# Out:
#   param_C  mean_test_score  rank_test_score
# 0     0.1         0.920000                5
# 1       1         0.966667                3
# 2      10         0.980000                1
# 3     100         0.973333                2
# 4    1000         0.960000                4

# %%
import matplotlib.pyplot as plt
C_values=result['param_C'].astype(float)
train_score=result['mean_train_score']
test_score=result['rank_test_score']
plt.plot(C_values,train_score,label='Train score',marker='o')
plt.plot(C_values,test_score,label='test_score',marker='o')
plt.xlabel('C value')
plt.ylabel('Accuracy')
plt.title('Train and test score for different C values')
plt.legend()
plt.grid(True)
plt.show()

# %%
print("Best accuracy score",grid.best_score_)
print("best c value",grid.best_params_['C'])
# Out:
# Best accuracy score 0.9800000000000001
# best c value 10
